# %% [markdown]
# This is a simple notebook to get started in this dataset

# %%
import numpy as np
import pandas as pd

# %%
crime = pd.read_csv('londoncrime.csv')

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

mpl.style.use('ggplot')

print('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.3.4

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
crime.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
crime.tail()
# Out:
#           lsoa_code     borough               major_category  \
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6

# %%
crime.shape
# Out:
# (13490604, 7)

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
crime.isnull().sum()
# Out:
# lsoa_code         0
# borough           0
# major_category    0
# minor_category    0
# value             0
# year              0
# month             0
# dtype: int64

# %%
crime.describe()
# Out:
#               value          year         month
# count  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00
# std    1.771513e+00  2.581989e+00  3.452053e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00
# 25%    0.000000e+00  2.010000e+03  3.750000e+00
# 50%    0.000000e+00  2.012000e+03  6.500000e+00
# 75%    1.000000e+00  2.014000e+03  9.250000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %% [markdown]
# # Area Plot

# %%
crime2=crime.groupby('year', as_index=True).agg({"value":"sum"})

# %%
crime2
# Out:
#        value
# year
# 2008  738641
# 2009  717214
# 2010  715324
# 2011  724915
# 2012  737329
# 2013  686407
# 2014  680183
# 2015  711624
# 2016  736121

# %%
crime2.plot()

plt.title('Crime Trends in London from 2008-2009')
plt.ylabel('Number of Crimes')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
crime3=crime.groupby('borough', as_index=False).agg({"value":"sum"}).sort_values(by=["value"], ascending=[True])

# %%
crime3
# Out:
#                    borough   value
# 6           City of London     780
# 20    Kingston upon Thames   89306
# 26    Richmond upon Thames   96771
# 28                  Sutton  100987
# 2                   Bexley  114136
# 23                  Merton  115654
# 14                  Harrow  116848
# 15                Havering  138947
# 0     Barking and Dagenham  149447
# 19  Kensington and Chelsea  171981
# 10               Greenwich  181568
# 25               Redbridge  183562
# 4                  Bromley  184349
# 12  Hammersmith and Fulham  185259
# Hammersmith and Fulham  19848  20174  185259
# Haringey                24626  27174  213272
# Harrow                  12601  13153  116848
# Havering                15870  16903  138947
# Hillingdon              23234  24341  209680
# Hounslow                21286  22251  186772
# Islington               27032  27092  230286
# Kensington and Chelsea  19070  19580  171981
# Kingston upon Thames     9738   9983   89306
# Lambeth                 33164  34071  292178
# Lewisham                23437  23904  215137
# Merton                  12273  12755  115654
# Newham                  29217  30090  262024
# Redbridge               18897  19502  183562
# Richmond upon Thames    10413  11074   96771
# Southwark               30260  31636  278809
# Sutton                  10598  10658  100987
# Tower Hamlets           27493  29253  228613
# Waltham Forest          20969  20716  203879
# Wandsworth              22401  23679  204741
# Westminster             47395  48330  455028

# %%
crime4.sort_values(by='Total', ascending=False, axis=0, inplace=True)
crime5 = crime4.head(5) 
crime5
# Out:
# year          2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# borough
# Westminster  47846  48456  48116  54243  59226  53852  47564  47395  48330
# Lambeth      31717  31225  31671  33224  33473  31868  31765  33164  34071
# Southwark    33470  30623  31320  30723  30737  31128  28912  30260  31636
# Camden       32010  31612  31804  33956  31472  28435  27198  29477  29183
# Newham       29752  28610  30728  27978  30067  27577  28005  29217  30090
#
# year          Total
# borough
# Westminster  455028
# Lambeth      292178
# Southwark    278809
# Camden       275147
# Newham       262024

# %%
crime5.drop('Total', axis=1, inplace=True) #drop Total
crime5
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# year          2008   2009   2010   2011   2012   2013   2014   2015   2016
# borough
# Westminster  47846  48456  48116  54243  59226  53852  47564  47395  48330
# Lambeth      31717  31225  31671  33224  33473  31868  31765  33164  34071
# Southwark    33470  30623  31320  30723  30737  31128  28912  30260  31636
# Camden       32010  31612  31804  33956  31472  28435  27198  29477  29183
# Newham       29752  28610  30728  27978  30067  27577  28005  29217  30090

# %%
crime5=crime5.transpose() #transpose
crime5
# Out:
# borough  Westminster  Lambeth  Southwark  Camden  Newham
# year
# 2008           47846    31717      33470   32010   29752
# 2009           48456    31225      30623   31612   28610
# 2010           48116    31671      31320   31804   30728
# 2011           54243    33224      30723   33956   27978
# 2012           59226    33473      30737   31472   30067
# 2013           53852    31868      31128   28435   27577
# 2014           47564    31765      28912   27198   28005
# 2015           47395    33164      30260   29477   29217
# 2016           48330    34071      31636   29183   30090

# %%
crime5.index=crime5.index.map(int)

# %%
crime5.plot(kind='area',
         alpha=0.25,
         stacked=False,
         figsize=(20,10))
plt.ylabel('Number of Crimes')
plt.xlabel('Years')
plt.title('Top 5 Areas With The Most Crime')
# Out:
# Text(0.5, 1.0, 'Top 5 Areas With The Most Crime')

# %% [markdown]
# # Histogram

# %%
crime4[2016].head()
# Out:
# borough
# Westminster    48330
# Lambeth        34071
# Southwark      31636
# Camden         29183
# Newham         30090
# Name: 2016, dtype: int64

# %%
count, bin_edges=np.histogram(crime4[2016])
print(count)
print(bin_edges)
# Out:
# [ 1  0  6  2 10  8  4  1  0  1]
# [  178.   4993.2  9808.4 14623.6 19438.8 24254.  29069.2 33884.4 38699.6
#  43514.8 48330. ]

# %%
crime4[2016].plot(kind='hist',figsize=(8,5), xticks=bin_edges)
plt.ylabel('Number of Boroughs')
plt.xlabel('Number of Crimes')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# # Pie Chart

# %%
crime5=crime.groupby('major_category', as_index=True).agg({"value":"sum"}).sort_values(by=['value'],ascending=[False])

# %%
crime5.plot.pie(y='value', 
                    figsize=(15,6),
                   autopct='%1.1f%%',
                   startangle=90,
                   shadow=True,
                   labels=None,
                   pctdistance=1.12)
plt.legend(labels=crime5.index, loc='upper left')
plt.axis('equal')
# Out:
# (-1.1231601551367114,
#  1.1088943210782847,
#  -1.1330414213370075,
#  1.1015734010179887)

# %% [markdown]
# # Box Plot

# %%
crime6 = crime4.loc[['Westminster']].transpose()
crime6 = crime6.drop(['Total'])

# %%
crime6.plot(kind='box', figsize=(8,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Plot

# %%
crime7= pd.DataFrame(crime4.sum(axis=0))
crime7
# Out:
#              0
# year
# 2008    738641
# 2009    717214
# 2010    715324
# 2011    724915
# 2012    737329
# 2013    686407
# 2014    680183
# 2015    711624
# 2016    736121
# Total  6447758

# %%
crime7=crime7.drop(['Total'])
crime7
# Out:
#            0
# year
# 2008  738641
# 2009  717214
# 2010  715324
# 2011  724915
# 2012  737329
# 2013  686407
# 2014  680183
# 2015  711624
# 2016  736121

# %%
crime7=crime7.rename(columns={0:'Total'})
crime7
# Out:
#        Total
# year
# 2008  738641
# 2009  717214
# 2010  715324
# 2011  724915
# 2012  737329
# 2013  686407
# 2014  680183
# 2015  711624
# 2016  736121

# %%
crime7.reset_index(inplace=True)

# %%
crime7
# Out:
#    year   Total
# 0  2008  738641
# 1  2009  717214
# 2  2010  715324
# 3  2011  724915
# 4  2012  737329
# 5  2013  686407
# 6  2014  680183
# 7  2015  711624
# 8  2016  736121

# %%
crime7.plot(kind='scatter',
        x='year',
        y='Total',
        figsize=(10,6),
        color='darkblue')

plt.title('Number of Crimes at Westminster 2008 - 2016')
plt.xlabel('Years')
plt.ylabel('Total Crimes')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %% [markdown]
# # World Map (Folium)

# %%
import folium

# %%
# !pip install geojson
import geojson as gj
# Out:
# Requirement already satisfied: geojson in c:\users\lenovo\anaconda3\lib\site-packages (2.5.0)

# %%
world_map = folium.Map(location=[51.507822097714055, -0.12786449729312158], zoom_start=13, tiles='Stamen Terrain')
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_742c1364dbca4de89b8d26daddcd6918%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_742c1364dbca4de89b8d26daddcd6918%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_742c1364dbca4de89b8d26daddcd6918%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_742c1364dbca4de89b8d26daddcd6918%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B51.507822097714055%2C%20-0.12786449729312158%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
london_geo = r'london_borough.geojson'
world_map = folium.Map(location=[51.507822097714055, -0.12786449729312158], zoom_start=9)
folium.Choropleth(geo_data=london_geo,
                 data=crime4,
                 columns=[crime4.index, 'Total'],
                 key_on='feature.properties.name',
                 fill_color='YlOrRd',
                 fill_opacity=0.7,
                 line_opacity=0.2,
                 legend_name='Crimes in London').add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c71aa1c4e16843548e6a3ee9d5324c1a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c71aa1c4e16843548e6a3ee9d5324c1a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c71aa1c4e16843548e6a3ee9d5324c1a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c71aa1c4e16843548e6a3ee9d5324c1a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
london_crime = open('londoncrime.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
london_wc = WordCloud(
    background_color='white',
    max_words=2500,
    stopwords=stopwords
)

#generate the word cloud
london_wc.generate(london_crime)

# %%
plt.imshow(london_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
fig = plt.figure()
fig.set_figwidth(14) 
fig.set_figheight(18)

plt.imshow(london_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Finish
